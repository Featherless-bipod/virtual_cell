# %%
import scanpy as sc
import numpy as np
import pandas as pd
import data_cleaning as dc

# %%
adata = sc.read_h5ad('vcc_data/adata_Training.h5ad')
gene_names = pd.read_csv('vcc_data/gene_names.csv', header= None)

# %%
control_data = dc.get_control_data(adata)

# %%
control_data.shape
# Out:
# (38176, 18080)

# %%
count
# Out:
# 38176

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 221273 × 18080
#     obs: 'target_gene', 'guide_id', 'batch'
#     var: 'gene_id'

# %%
dc.adaptive_clean_and_preprocess_data(adata)
# Out:
# --- Starting ADAPTIVE Data Cleanup and Pre-processing ---
# Initial shape: 221273 cells x 18080 genes
# Step 1 & 2: Calculated and visualizing QC metrics...
# Step 3: Calculating adaptive filtering thresholds...
#   - Using min_genes_per_cell: 200
#   - Calculated max_genes_per_cell: 10324
#
# Step 4: Applying filters sequentially...
#    Filtering complete. Shape is now: 218403 cells x 18010 genes
# Step 5: Saved original raw counts to adata.layers['counts']
#
# --- Normalizing and Transforming Data ---
# Steps 6 & 7: Normalization and Log1p transformation complete.
#
# --- Pre-processing Complete. ---
# AnnData object with n_obs × n_vars = 218403 × 18010
#     obs: 'target_gene', 'guide_id', 'batch', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'n_genes'
# ...

# %%
adata.shape

# %%
adata.shape

# %%
min_genes_per_cell = 200
max_genes_per_cell = 10000

# %%
sc.pp.calculate_qc_metrics(skibidi, inplace =True)

# %%
sc.pp.filter_cells(adata)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sc.pp.filter_cells(adata)
#
# File ~/Library/Python/3.12/lib/python/site-packages/legacy_api_wrap/__init__.py:82, in legacy_api.<locals>.wrapper.<locals>.fn_compatible(*args_all, **kw)
#      79 @wraps(fn)
#      80 def fn_compatible(*args_all: P.args, **kw: P.kwargs) -> R:
#      81     if len(args_all) <= n_positional:
# ---> 82         return fn(*args_all, **kw)
#      84     args_pos: P.args
#      85     args_pos, args_rest = args_all[:n_positional], args_all[n_positional:]
#
# File ~/Library/Python/3.12/lib/python/site-packages/scanpy/preprocessing/_simple.py:158, in filter_cells(data, min_counts, min_genes, max_counts, max_genes, inplace, copy)
#     153 if n_given_options != 1:
#     154     msg = (
#     155         "Only provide one of the optional parameters `min_counts`, "
# ...

# %%
len(gene_names)

# %%
adata.shape
# Out:
# (212036, 18080)

# %%
adata.X.shape

# %%
adata.obs.shape

# %%
adata.var.shape
