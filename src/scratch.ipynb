# %%
import scanpy as sc
import numpy as np
import pandas as pd
import data_cleaning as dc
import pyensembl
import position_encoding as pos
import mamba
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 import pandas as pd
#       4 import data_cleaning as dc
# ----> 5 import pyensembl
#       6 import position_encoding as pos
#       7 import mamba
#
# ModuleNotFoundError: No module named 'pyensembl'

# %%
import scanpy as sc

# %%
adata = sc.read_h5ad('../vcc_data/adata_Training.h5ad')
